# %%
a='this is ranjeet's pen'
# Out:
#   File "<ipython-input-1-6a73815a464d>", line 1
#     a='this is ranjeet's pen'
#                        ^
# SyntaxError: invalid syntax

# %%
a="this is ranjeet's pen"

# %%
a="this is ranjeet's pen"
b='this is ranjeet\'s pen'
a,b
a + b
a=b

# %%
a="this is ranjeet's pen"
b='this  ranjeet\'s pen'
c=a=b
d=a<b
print(d)
print(c)
# Out:
# False
# this  ranjeet's pen

# %%
a='this is a string'
a.split()
# Out:
# ['this', 'is', 'a', 'string']

# %%
a.split('is')
# Out:
# ['th', ' ', ' a string']

# %%
a.replace('is','are')
# Out:
# 'thare are a string'

# %%
a.find('is')
# Out:
# 2

# %%
a.find('isff')
# Out:
# -1

# %%
a.upper()
# Out:
# 'THIS IS A STRING'

# %%
a.islower()
# Out:
# True

# %%
a.isalpha()
# Out:
# False

# %%
s = "abcd"
s.upper()
print(s)
# Out:
# abcd

# %% [markdown]
# # slicing

# %%
a='this is slicing'

# %%
a[2:5]
# Out:
# 'is '

# %%
a[2:10:2]
# Out:
# 'i ss'

# %%
s=input()
a='x'
b='y'
p=s.find(a)
ans=s
if p!=-1:
    ans=s[:p]+b+s[p+1:]
ans
# Out:
# abcdxjk
# 'abcdyjk'

# %%
s=input()
a='x'
b='y'
p=s.find(a)
ans=s
for i in range(0,len(ans)):
    if ans[i]==a:
        ans=ans[:i]+b+ans[i+1:]
ans

# %%
str1 = 'hello'
print(str1[-1:])
# Out:
# o

# %%
s = "abcdefghi"
s[-3:-1]
# Out:
# 'gh'

# %%
string=input()
ans=string
ans=string[::-1]
print(ans,end='')
# Out:
# ran
# nar

# %%
n=input()

print(n)
ans=[n[i:j]
for i in range(len(n))
    for j in range(i+1,len(n)+1)]
print(ans)
# Out:
# ran
# ran
# ['r', 'ra', 'ran', 'a', 'an', 'n']

# %%
n=input()
i=0
while i<=len(n):
    j=0
    while j<=i:
        print(n[j],end='')
        j=j+1
    print()
    i=i+1
# Out:
# ranjeet
# r
# ra
# ran
# ranj
# ranje
# ranjee
# ranjeet
# ranjeet
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-67-ed5a1a352ea8> in <module>
#       4     j=0
#       5     while j<=i:
# ----> 6         print(n[j],end='')
#       7         j=j+1
#       8     print()
#
# IndexError: string index out of range

# %%
from sys import stdin


def printSubstrings(string) :
	# Your ciode goes here
    for i in range(len(n)):
        for j in range(i+1,len(n)+1):
            print (string[i:j])
    return





#main
string = stdin.readline().strip();
printSubstrings(string)

# %%
n=input()
for i in range(len(n)):
    for j in range(i+1,len(n)+1):
        print (n[ i : j ])
# Out:
# ran
# r
# ra
# ran
# a
# an
# n

# %%
# Out:
# ran
# r
# ra
# ran
# a
# an
# n

# %%
ran
r
ra
ran
a
an
n

# %%
n=int(input())
r=''
while n!=0:
    r=n%2
    
    print(type(r))
    n=n//2
#for i in range()
# Out:
# 7
# <class 'int'>
# <class 'int'>
# <class 'int'>
